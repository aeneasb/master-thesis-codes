# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import datetime
import os
import ids
from PIL import Image
import time
import tifffile

# %%
today=datetime.datetime.now().year,datetime.datetime.now().month,datetime.datetime.now().day
Folder_name='-'.join(map(str,today))
print('Current data is recorded in the folder ' + Folder_name)
filepath = 'home/user/Desktop/Data/'+str(Folder_name)

#if already created, don't create.
try:
    os.mkdir(Folder_name)
except:
    pass

# %%
cam = ids.Camera()
cam.color_mode = ids.ids_core.COLOR_RGB8  # Get images in RGB format
cam.exposure = 5
cam.auto_exposure=True
cam.auto_exposure_brightness=True
cam.auto_white_balance=True
cam.continuous_capture = True
#cam.continuous_capture = False  # Stop capture to change color mode
#cam.color_mode = ids.ids_core.COLOR_BGR8

for u in range(14):
    for i in range(7):
        meta = cam.next_save('ids_'+str(u+i)+'.jpg')
        ser.write(b'GR,28000,0\r\n'); time.sleep(2) #move relatively 100000 
    ser.write(b'GR,-196000,28000\r\n'); time.sleep(2)

# %%
#Configure serial port

import serial
with serial.Serial('/dev/ttyACM0', timeout=1) as ser:
    x = ser.read()
    s = ser.read(10)
    line = ser.readline()
ser.open()

# %%
cam = ids.Camera()
cam.color_mode = ids.ids_core.COLOR_RGB8
cam.exposure = 5
cam.auto_exposure=True
cam.continuous_capture = True


stitch=[]
for u in range(14):
    for i in range(7):
        img,meta=cam.next() #Get image as a numpy array
        stitch.append(img)
        ser.write(b'GR,28000,0\r\n'); time.sleep(2)
    ser.write(b'GR,-196000,28000\r\n'); time.sleep(2)
stitch=np.asarray(stitch)
print 'stitch has shape: {}'.format(stitch.shape)
# Out:
# WARNING:ids:Out of memory locations for images (1520 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (6 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (6 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (12 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (6 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (11 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# WARNING:ids:Out of memory locations for images (5 instances)
# stitch has shape: (98, 1920, 2560, 3)

# %%
pil_img = Image.fromarray(img)
pil_img.save("pil.jpg", quality=95)

# %%
ser.write(b'GR,196000,0\r\n') #move relatively 100000 
#100 = 1um
#Diameter of one field of view: 700um
# Out:
# 13

# %%
#cam = ids.Camera()
cam.color_mode = ids.ids_core.COLOR_RGB8
cam.exposure = 5
cam.auto_exposure=True
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-14-6f6447e85c08> in <module>()
#       1 #cam = ids.Camera()
# ----> 2 cam.color_mode = ids.ids_core.COLOR_RGB8
#       3 cam.exposure = 5
#       4 cam.auto_exposure=True
#       5
#
# /home/user/anaconda2/lib/python2.7/site-packages/ids.pyc in color_mode(self, val)
#     158     def color_mode(self, val):
#     159         if self.continuous_capture:
# --> 160             raise IOError("Color cannot be changed while capturing images")
#     161
#     162         ids_core.Camera.color_mode.__set__(self, val)
#
# IOError: Color cannot be changed while capturing images

# %%
cam.continuous_capture = True
img2,meta=cam.next()
cam.continuous_capture = False
# Out:
# ---------------------------------------------------------------------------
# IDSError                                  Traceback (most recent call last)
# <ipython-input-13-3db7167995ce> in <module>()
# ----> 1 cam.continuous_capture = True
#       2 img2,meta=cam.next()
#       3 cam.continuous_capture = False
#
# IDSError: uEye SDK error 1: Unknown error

# %%
plt.figure(figsize=(35,15))
plt.imshow(img)

# %%
#cam.free_all()
# Closes open camera
cam.close()
# Out:
# ---------------------------------------------------------------------------
# IDSError                                  Traceback (most recent call last)
# <ipython-input-15-de1a8bb955a1> in <module>()
#       1 #cam.free_all()
#       2 # Closes open camera
# ----> 3 cam.close()
#
# IDSError: uEye SDK error 1: Unknown error

# %%
num_ports = 2
# power cycle USB ports
for i in range(num_ports):
    # disable ASLR
    os.system('echo 0 | sudo tee /sys/bus/usb/devices/usb' + str(i+1) + '/power/autosuspend')

# %%
plot_image = np.concatenate((stitch[0,:,:,1], stitch[1,:,:,1]), axis=1)
plt.figure(figsize=(35,15))
plt.imshow(plot_image)

# %%
cam = ids.Camera()
cam.color_mode = ids.ids_core.COLOR_RGB8
cam.exposure = 5
cam.auto_exposure=True
cam.continuous_capture = True

for i in range(7):
    meta = cam.next_save('ids_'+str(i)+'.jpg');time.sleep(1)
    ser.write(b'GR,28000,0\r\n');time.sleep(1)
# Out:
# WARNING:ids:Out of memory locations for images (4801 instances)
# WARNING:ids:Out of memory locations for images (1 instances)

# %%
ofn = '/home/user/Desktop/Data/2017-10-17/tifffile.tif'

# %%
tifffile.imsave(str(ofn),stitch,compress=6)
